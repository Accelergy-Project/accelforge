# %%
import accelforge as af

spec = af.Spec.from_yaml(
    af.examples.arches.simple_heterogeneous,
    af.examples.workloads.matmuls,
    af.examples.mappings.with_binding.fused_matmuls_to_simple_heterogeneous,
    jinja_parse_data={"N_EINSUMS": 3},
)

mappings = spec.evaluate_mapping()

# %%
list(mappings.data.columns)
# Out:
# ['tensor<SEP>T1',
#  'Total<SEP>energy',
#  'Total<SEP>leak_energy',
#  'Total<SEP>dynamic_energy',
#  'tensor<SEP>T2',
#  'reservation<SEP>GlobalBuffer<SEP>-1<SEP>left<SEP>0',
#  'reservation<SEP>MainMemory<SEP>-1<SEP>left<SEP>0',
#  'Total<SEP>latency<SEP>0',
#  'Matmul0<SEP>usage<SEP>memory<SEP>GlobalBuffer<SEP>T0',
#  'Matmul0<SEP>usage<SEP>memory<SEP>MainMemory<SEP>T0',
#  'Matmul0<SEP>usage<SEP>memory<SEP>GlobalBuffer<SEP>T1',
#  'Matmul0<SEP>usage<SEP>memory<SEP>GlobalBuffer<SEP>W0',
#  'Matmul0<SEP>usage<SEP>memory<SEP>MainMemory<SEP>W0',
#  'Matmul0<SEP>action<SEP>GlobalBuffer<SEP>T0<SEP>read',
#  'Matmul0<SEP>action<SEP>GlobalBuffer<SEP>T0<SEP>write',
#  'Matmul0<SEP>action<SEP>MainMemory<SEP>T0<SEP>read',
#  'Matmul0<SEP>action<SEP>MainMemory<SEP>T0<SEP>write',
#  'Matmul0<SEP>action<SEP>GlobalBuffer<SEP>T1<SEP>read',
#  'Matmul0<SEP>action<SEP>GlobalBuffer<SEP>T1<SEP>write',
#  'Matmul0<SEP>action<SEP>GlobalBuffer<SEP>W0<SEP>read',
# ...

# %%
mappings

# %%
df = mappings.data
df[[c for c in df if "latency" in c]]
# Out:
#    Total<SEP>latency<SEP>0  Matmul0<SEP>latency<SEP>MacA  \
# 0                2097152.0                     2097152.0
#
#    Matmul0<SEP>latency<SEP>GlobalBuffer  Matmul0<SEP>latency<SEP>MainMemory  \
# 0                                   0.0                                 0.0
#
#    Matmul1<SEP>latency<SEP>MacB  Matmul1<SEP>latency<SEP>GlobalBuffer  \
# 0                     2097152.0                                   0.0
#
#    Matmul1<SEP>latency<SEP>MainMemory  Matmul2<SEP>latency<SEP>MacA  \
# 0                                 0.0                     2097152.0
#
#    Matmul2<SEP>latency<SEP>GlobalBuffer  Matmul2<SEP>latency<SEP>MainMemory
# 0                                   0.0                                 0.0
