# %%
import os
import pickle

from fastfusion.frontend.arch import Memory
from fastfusion.frontend.specification import Specification

import copy
import time
from fastfusion import Specification
from fastfusion.mapper import Metrics

from fastfusion.mapper.FFM._pmapping_group import PmappingGroup
from fastfusion.mapper.FFM import make_pmappings, join_pmappings

# %%
spec = Specification.from_yaml(
    "architectures/fastfusion/tpu_like.yaml",
    "workloads/fastfusion/gemm_16k.yaml"
)

pmappings = make_pmappings(spec)
# Out:
# WARNING Loading configuration file from /home/gilbertm/work/venv/fastfusion/config.yaml
# Generating pmapping templates for compute scalar_unit Einsum Matmul: 0it [00:00, ?it/s]           | 0/2 [00:00<?, ?it/s]
# Generating pmapping templates for compute MAC Einsum Matmul: 8it [00:00, 82.23it/s]       | 1/2 [00:01<00:01,  1.30s/it]
# Generating jobs: 100%|████████████████████████████████████████████████████████████████████| 2/2 [00:01<00:00,  1.42it/s]
# WARNING Einsum Matmul has 8 pmapping templates:
# WARNING 	[WA,I,A in MainMemory] T-m,na [A in GlobalBuffer] T-ni [I in GlobalBuffer] T-na S-Z-m S-Y-ni S-X-na [WA in Register] T-m MAC computes Matmul
# WARNING 	[WA,I,A in MainMemory] T-m,ni [I in GlobalBuffer] T-na [A in GlobalBuffer] T-ni S-Z-m S-Y-ni S-X-na [WA in Register] T-m MAC computes Matmul
# WARNING 	[WA,I,A in MainMemory] T-m,na [A in GlobalBuffer] T-ni [I in GlobalBuffer] T-na [WA in GlobalBuffer] T-m S-Z-m S-Y-ni S-X-na MAC computes Matmul
# WARNING 	[WA,I,A in MainMemory] T-m,na [A in GlobalBuffer] T-ni [WA in GlobalBuffer] T-m [I in GlobalBuffer] T-na S-Z-m S-Y-ni S-X-na MAC computes Matmul
# WARNING 	[WA,I,A in MainMemory] T-m,ni [I in GlobalBuffer] T-na [A in GlobalBuffer] T-ni [WA in GlobalBuffer] T-m S-Z-m S-Y-ni S-X-na MAC computes Matmul
# WARNING 	[WA,I,A in MainMemory] T-m,ni [I in GlobalBuffer] T-na [WA in GlobalBuffer] T-m [A in GlobalBuffer] T-ni S-Z-m S-Y-ni S-X-na MAC computes Matmul
# WARNING 	[WA,I,A in MainMemory] T-na,ni [WA in GlobalBuffer] T-m [A in GlobalBuffer] T-ni [I in GlobalBuffer] T-na S-Z-m S-Y-ni S-X-na MAC computes Matmul
# WARNING 	[WA,I,A in MainMemory] T-na,ni [WA in GlobalBuffer] T-m [I in GlobalBuffer] T-na [A in GlobalBuffer] T-ni S-Z-m S-Y-ni S-X-na MAC computes Matmul
# WARNING Insufficient jobs available to utilize available threads. Splitting jobs into smaller chunks.
# Generating pmappings:   0%|                                                                       | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/gilbertm/work/venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "/home/gilbertm/work/venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/venv/lib/python3.12/site-packages/joblib/parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/mapper_one_einsum/mapper_one_einsum.py", line 90, in generate_pmappings
#     result, n_pmappings = explore_tile_shapes(job)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/tile_shape_exploration/tile_shape_exploration.py", line 182, in explore_tile_shapes
#     return _explore_tile_shapes(job)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/tile_shape_exploration/tile_shape_exploration.py", line 1777, in _explore_tile_shapes
#     return _explore_tile_shapes_old(job)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/tile_shape_exploration/tile_shape_exploration.py", line 113, in _explore_tile_shapes_old
#     symbols, symbolic_df, per_memory_occupancy_df, utilization_df = run_model(job)
#                                                                     ^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/tile_shape_exploration/tile_shape_exploration.py", line 856, in run_model
#     reuse = analyze_reuse_and_add_reservations_to_mapping(job)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 399, in analyze_reuse_and_add_reservations_to_mapping
#     result = analyze_node(0, einsum_shape, info)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 574, in analyze_node
#     return class2analysis_function[type(node)](node_idx, current_shape, info)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 753, in analyze_storage
#     child_result = analyze_node(node_idx+1, current_shape, info)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 574, in analyze_node
#     return class2analysis_function[type(node)](node_idx, current_shape, info)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 859, in analyze_reservation
#     child_result = analyze_node(node_idx+1, current_shape, info)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 574, in analyze_node
#     return class2analysis_function[type(node)](node_idx, current_shape, info)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 753, in analyze_storage
#     child_result = analyze_node(node_idx+1, current_shape, info)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 574, in analyze_node
#     return class2analysis_function[type(node)](node_idx, current_shape, info)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 859, in analyze_reservation
#     child_result = analyze_node(node_idx+1, current_shape, info)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 574, in analyze_node
#     return class2analysis_function[type(node)](node_idx, current_shape, info)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 753, in analyze_storage
#     child_result = analyze_node(node_idx+1, current_shape, info)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 574, in analyze_node
#     return class2analysis_function[type(node)](node_idx, current_shape, info)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 859, in analyze_reservation
#     child_result = analyze_node(node_idx+1, current_shape, info)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 574, in analyze_node
#     return class2analysis_function[type(node)](node_idx, current_shape, info)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 581, in analyze_temporal
#     stride_and_shape = get_stride_and_tile_shape(node, current_shape, node_idx)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/model/looptree/reuse/summarized/symbolic.py", line 1024, in get_stride_and_tile_shape
#     raise ValueError(f"Neither tile_shape, factor, nor tile_pattern found")
# ValueError: Neither tile_shape, factor, nor tile_pattern found
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       1 spec = Specification.from_yaml(
#       2     "architectures/fastfusion/tpu_like.yaml",
#       3     "workloads/fastfusion/gemm_16k.yaml"
#       4 )
# ----> 6 pmappings = make_pmappings(spec)
#
# File ~/work/active/fastfusion/fastfusion/mapper/FFM/_interface/main.py:37, in make_pmappings(spec, einsum_names, tagger)
#      35 parsed_spec.calculate_component_energy_area(area=False)
#      36 flattened_arches = parsed_spec.get_flattened_architecture()
# ---> 37 sims, pmapping_objects, einsum2jobs = get_sims(
#      38     parsed_spec,
#      39     flattened_arches,
#      40     tagger=tagger,
#      41     metrics=spec.mapper.ffm.metrics,
#      42     einsum_names=einsum_names
#      43 )
#      44 resource2capacity = {}
#      45 for flattened_arch in flattened_arches:
#
# File ~/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/mapper_multi_einsum.py:249, in get_sims(spec, flattened_arches, tagger, metrics, einsum_names, fail_if_no_pmappings_for_einsum)
#     247 sims = {einsum_name: [] for einsum_name in spec.workload.einsum_names}
#     248 return_jobs = {}
# --> 249 for einsum_name, new_sims, pmappings, jobs_with_similar_compatibilities in parallel(
#     250     calls,
#     251     pbar=f"Generating pmappings",
#     252     return_as="generator_unordered",
#     253 ):
#     254     sims[einsum_name].extend(new_sims)
#     255     pmapping_objects.setdefault(einsum_name, {}).update(pmappings)
#
# File ~/work/active/fastfusion/fastfusion/util/util.py:133, in parallel.<locals>.yield_results()
#     132 def yield_results():
# --> 133     for result in Parallel(n_jobs=n_jobs, **args)(jobs):
#     134         if pbar:
#     135             pbar.update(1)
#
# File ~/work/venv/lib/python3.12/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/work/venv/lib/python3.12/site-packages/joblib/parallel.py:1784, in Parallel._retrieve(self)
#    1778 while self._wait_retrieval():
#    1779     # If the callback thread of a worker has signaled that its task
#    1780     # triggered an exception, or if the retrieval loop has raised an
#    1781     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1782     # worker traceback.
#    1783     if self._aborting:
# -> 1784         self._raise_error_fast()
#    1785         break
#    1787     nb_jobs = len(self._jobs)
#
# File ~/work/venv/lib/python3.12/site-packages/joblib/parallel.py:1859, in Parallel._raise_error_fast(self)
#    1855 # If this error job exists, immediately raise the error by
#    1856 # calling get_result. This job might not exists if abort has been
#    1857 # called directly or if the generator is gc'ed.
#    1858 if error_job is not None:
# -> 1859     error_job.get_result(self.timeout)
#
# File ~/work/venv/lib/python3.12/site-packages/joblib/parallel.py:758, in BatchCompletionCallBack.get_result(self, timeout)
#     752 backend = self.parallel._backend
#     754 if backend.supports_retrieve_callback:
#     755     # We assume that the result has already been retrieved by the
#     756     # callback thread, and is stored internally. It's just waiting to
#     757     # be returned.
# --> 758     return self._return_or_raise()
#     760 # For other backends, the main thread needs to run the retrieval step.
#     761 try:
#
# File ~/work/venv/lib/python3.12/site-packages/joblib/parallel.py:773, in BatchCompletionCallBack._return_or_raise(self)
#     771 try:
#     772     if self.status == TASK_ERROR:
# --> 773         raise self._result
#     774     return self._result
#     775 finally:
#
# ValueError: Neither tile_shape, factor, nor tile_pattern found
