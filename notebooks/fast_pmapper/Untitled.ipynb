# %%
def get_tpu_energy_reduction_potential(mac_energy, dram_energy, systolic_array_size):
    mac_energy = mac_energy*systolic_array_size
    return dram_energy*3 / (dram_energy*3 + mac_energy)

# %%
get_tpu_energy_reduction_potential(0.07, 56, 4*128)
# Out:
# 0.8241758241758241
